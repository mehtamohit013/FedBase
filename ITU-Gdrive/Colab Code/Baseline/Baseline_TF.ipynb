# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import matplotlib
# %matplotlib inline

# %%
# !python ./gdrive/MyDrive/BTP/Github_Repo/ITU-Challenge-ML5G-PHY-master/Beam_selection/code/main.py ./gdrive/MyDrive/BTP/Data/baseline_data/S08 --input lidar
# Out:
# 2021-04-16 13:10:06.365854: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-16 13:10:09.899318: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-16 13:10:09.927006: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-16 13:10:09.997534: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-04-16 13:10:09.997605: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (0882b91d8dec): /proc/driver/nvidia/version does not exist
# 2021-04-16 13:10:09.998453: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...
