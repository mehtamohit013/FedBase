# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !python /gdrive/MyDrive/BTP/Github_Repo/NU_Huskies/baseline_code/main.py --data_folder /gdrive/MyDrive/BTP/Data/baseline_data/S08/ --test_data_folder /gdrive/MyDrive/BTP/Data/baseline_data/S09/ --input lidar --epochs 50
# Out:
# 2021-04-18 09:35:19.681508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Argumen parser inputs Namespace(Aug=False, augmented_folder='G:/Beam_Selection_ITU/beam_selection/baseline_code_modified/aug_data/', bs=32, data_folder='/gdrive/MyDrive/BTP/Data/baseline_data/S08/', epochs=50, fusion_architecture='mlp', id_gpu=1, image_feature_to_use='v1', img_version='', input=['lidar'], lr=0.0001, model_folder='/home/batool/beam_selection_NU/baseline_code/model_folder/', restore_models=False, shuffle=True, strategy='one_hot', test_data_folder='/gdrive/MyDrive/BTP/Data/baseline_data/S09/')
# 2021-04-18 09:35:22.168887: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-18 09:35:22.169909: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# ...
