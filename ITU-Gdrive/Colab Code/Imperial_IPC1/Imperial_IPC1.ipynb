# %%
# !nvidia-smi
# Out:
# Tue Jun 29 10:50:37 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0    26W /  75W |      0MiB /  7611MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Running Github-PyTorch

# %%
# !pip install -r /gdrive/MyDrive/BTP/Github_Repo/Imperial_IPC1/pytorch/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 225kB 5.2MB/s
# ...

# %%
# !python /gdrive/MyDrive/BTP/Github_Repo/Imperial_IPC1/pytorch/beam_train_model.py --lidar_training_data /gdrive/MyDrive/BTP/Data/baseline_data/S08/lidar_input/lidar_train.npz /gdrive/MyDrive/BTP/Data/baseline_data/S08/lidar_input/lidar_validation.npz --beam_training_data /gdrive/MyDrive/BTP/Data/baseline_data/S08/beam_output/beams_output_train.npz /gdrive/MyDrive/BTP/Data/baseline_data/S08/beam_output/beams_output_validation.npz --lidar_validation_data /gdrive/MyDrive/BTP/Data/baseline_data/S09/lidar_input/lidar_test.npz --beam_validation_data /gdrive/MyDrive/BTP/Data/baseline_data/S09/beam_output/beams_output_test.npz

# %% [markdown]
# # Github-TF Repo

# %%
# !python /gdrive/MyDrive/BTP/Github_Repo/Imperial_IPC1/tensorflow/beam_train_model.py --lidar_training_data /gdrive/MyDrive/BTP/Data/baseline_data/S08/lidar_input/lidar_train.npz /gdrive/MyDrive/BTP/Data/baseline_data/S08/lidar_input/lidar_validation.npz --beam_training_data /gdrive/MyDrive/BTP/Data/baseline_data/S08/beam_output/beams_output_train.npz /gdrive/MyDrive/BTP/Data/baseline_data/S08/beam_output/beams_output_validation.npz --lidar_validation_data /gdrive/MyDrive/BTP/Data/baseline_data/S09/lidar_input/lidar_test.npz --beam_validation_data /gdrive/MyDrive/BTP/Data/baseline_data/S09/beam_output/beams_output_test.npz
# Out:
# 2021-06-29 10:41:34.752793: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-29 10:41:36.638575: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-29 10:41:36.699225: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-29 10:41:36.699871: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-06-29 10:41:36.699930: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !pip install tensorflow_federated
# Out:
# ...
#      |████████████████████████████████| 604kB 4.9MB/s
# ...
#      |████████████████████████████████| 51kB 5.8MB/s
# ...
#      |████████████████████████████████| 174kB 9.6MB/s
# ...
#      |████████████████████████████████| 194kB 9.9MB/s
# ...
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.28.1 which is incompatible.
# ERROR: pymc3 3.11.2 has requirement cachetools>=4.2.1, but you'll have cachetools 3.1.1 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement tqdm>=4.36.1, but you'll have tqdm 4.28.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Found existing installation: cachetools 4.2.2
#     Uninstalling cachetools-4.2.2:
#       Successfully uninstalled cachetools-4.2.2
#   Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
# ...

# %%
# !python /gdrive/MyDrive/BTP/Github_Repo/Imperial_IPC1/tensorflow/federated_beam.py
# Out:
# 2021-06-29 10:42:58.090653: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-29 10:43:02.666020: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-29 10:43:02.681504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-29 10:43:02.681940: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-06-29 10:43:02.681980: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...
