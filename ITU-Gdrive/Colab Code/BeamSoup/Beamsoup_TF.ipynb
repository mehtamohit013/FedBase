# %% [markdown]
# # Env

# %%
# !pip install open3d-python
# !pip uninstall -y tensorflow
# !pip install numpy==1.17.2
# !pip install open3d-python==0.7.0.0
# !pip install pandas==1.0.3 
# !pip install h5py==2.10.0
# !pip install keras==2.3.1
# !pip install tensorflow-gpu==1.14.0
# !pip install matplotlib==3.1.1
# !pip install tables==3.6.1
# %matplotlib inline
# Out:
# ...
#      |████████████████████████████████| 3.7MB 20.5MB/s
# ...

# %% [markdown]
# # .

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !python /gdrive/MyDrive/BTP/Github_Repo/BeamSoup/code/beam_train_frontend.py

# %%
# !python /gdrive/MyDrive/BTP/Github_Repo/BeamSoup/code/beam_test_model.py

# %%
# !python /gdrive/MyDrive/BTP/Github_Repo/BeamSoup/code/beam_train_model.py

# %%
# !wget https://nextcloud.lasseufpa.org/s/7FrX2883E4yorbB/download?path=%2FRaymobtime_s009%2Fraw_data\&files=s009_new_Blensor_rosslyn_scans_lidar.zip -O /gdrive/MyDrive/BTP/Data/raw_data/S09/scans

# %%
# !cd /gdrive/MyDrive/BTP/Data/raw_data/S09/scans2/s009_Blensor_rosslyn_scans_lidar;ls;for i in *.zip; do unzip "$i" -d "/gdrive/MyDrive/BTP/Data/raw_data/S09/scan_fin/${i%%.zip}"; done
# # !ls
# # !unzip '*.zip' -d /gdrive/MyDrive/BTP/Data/raw_data/S09/scans_unzipped

# %%
import numpy as np
import pandas as pd

# %%
coord_file = '/gdrive/MyDrive/BTP/Data/BeamSoup/coords_labels.h5'

# %%
y_true = pd.read_hdf(coord_file,key='val')

# %%
Y = y_true[['Labels']].to_numpy()
Y=np.array(Y[:,0].tolist())

# %%
y_true = np.argmax(Y,axis=1)

# %%
y_pred = np.loadtxt('beam_test_pred.csv',delimiter=',')

# %%
y_pred = np.loadtxt('pred.txt',delimiter=',')

# %%
y_pred = np.argsort(-y_pred,axis=1)

# %%
y_pred[0]

# %%
y_true[0]
# Out:
# 134

# %%
a = np.zeros((9638,256))

# %%
for i in range(0,9638):
    for j in range(0,256):
        a[i][j] = int(y_pred[i][j])

# %%
y_true[10]

# %%
y_pred[10,-50:-1]

# %%
pos=0
ovr = len(y_true)
for i in range(0,len(y_true)):
    if(float(y_true[i]) in y_pred[i,:50]):
        pos+=1

# %%
print(pos/ovr)

# %%
# !zip -r obstacles.zip obstacles_009

# %% [markdown]
# # Data

# %%
# !pip install boto3

# %%
# !pip install fs.sshfs
# import fs
# a = fs.open_fs("ssh://ubuntu:random1234@3.238.204.188:22/home/ubuntu/Data")

# %%
# !sudo apt install s3fs

# %%
client = boto3.client('s3')

# %%
import boto3
import sys

BUCKET_NAME = 'mohitmehtadata' # replace with your bucket name

# enter authentication credentials
s3 = boto3.resource('s3', aws_access_key_id = 'ASIA6IHFBZFYAQQFZUVJ', 
                          aws_secret_access_key= "slUnJWpfk8ZjqB9JR9iuj+42VqdFmiJloYKk4lxn",
                            aws_session_token = "...")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-6c05b36eb8a6> in <module>()
#       1 import boto3
# ----> 2 from boto3.s3.key import Key
#       3 import sys
#       4
#       5 BUCKET_NAME = 'mohitmehtadata' # replace with your bucket name
#
# ModuleNotFoundError: No module named 'boto3.s3.key'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def percent_cb(complete, total):
    sys.stdout.write('.')
    sys.stdout.flush()

# %%
testfile = './training.cpp'

# %%
k = Key(s3)
k.key = 'test.cpp'
k.set_contents_from_filename(testfile,
    cb=percent_cb, num_cb=10)

# %%
KEY = 'ab.cpp'
# try:
  # we are trying to download training dataset from s3 with name `my-training-data.csv` 
  # to colab dir with name `training.csv`
s3.Bucket(BUCKET_NAME).download_file(KEY, 'training.cpp')
  
# except botocore.exceptions.ClientError as e:
#   if e.response['Error']['Code'] == "404":
#     print("The object does not exist.")
#   else:
#     raise

# %%
import fs
import fs.opener
import fs.opener.sshfs

fs.opener.registry.install(fs.opener.sshfs.SSHOpener)
a = fs.open_fs("ssh://ubuntu:Random.12345@23.96.3.111:22/home/ubuntu/Data")

# %%
import numpy as np
import os
lidar_data = '/gdrive/MyDrive/BTP/Data/BeamSoup/lidar_data'
lidar_008 = os.path.join(lidar_data,'lidar_009.npz')
lidar_data_008 = np.load(lidar_008)['input']
lidar_save = './S009_npz'
os.makedirs(lidar_save,exist_ok=True)
for i in range(0,lidar_data_008.shape[0]):
    if(i%1000==0):
        print(f'{i} files have been saved')
    try:
        # f = a.open((lidar_save+'/'+str(i)+'.npz', 'wb')
        np.savez_compressed(lidar_save+'/'+str(i)+'.npz',input = lidar_data_008[i])
    except:
        print(f'Error in id {i}')

# %%
# !zip -r -q S009.zip S009_npz
f = open("S009.zip", 'rb')
a.upload('./S009.zip', f)

# %%
f = open("S010.zip", 'wb')
a.download('S009.zip', f)

# %%
# !diff S009.zip S010.zip

# %%
# os.makedirs('/gdrive/MyDrive/BTP/Data/BeamSoup/lidar_data/lidar_sparse/S008_npz',exist_ok = True)
# os.makedirs('/gdrive/MyDrive/BTP/Data/BeamSoup/lidar_data/lidar_sparse/S009_npz',exist_ok = True)

# %%
# !rsync -r --info=progress2 S008_npz /gdrive/MyDrive/BTP/Data/BeamSoup/lidar_data/lidar_sparse
# !rsync -r --info=progress2 S009_npz /gdrive/MyDrive/BTP/Data/BeamSoup/lidar_data/lidar_sparse
# Out:
#      15,247,762 100%  161.46kB/s    0:01:32 (xfr#11194, to-chk=0/11195)
#      14,899,458 100%  105.61kB/s    0:02:17 (xfr#9638, to-chk=0/9639)

# %%
# !zip -r -q S009.zip S009

# %%
lidar_save
# Out:
# './S008'

# %%
for i in range(3000,4000):
    a = np.load(lidar_save+'/'+str(i)+'.npz')['input']

# %%
import time

# %%
avg_time = 0
cnt = 0
for i in range(9000,9638):
    try:
        start = time.time()
        a = np.load(lidar_save+'/'+str(i)+'.npy')
        avg_time += -(start - time.time())
        cnt+=1
        if(i%1000==0):
            print(f'{i} queries verified')
        if(i>=9638):
            print(i)
    except:
        if(i<9638):
            print(f'Missing id is {i}')


print(avg_time/cnt,cnt)
# Out:
# 9000 queries verified
# 0.0030651402697667806 638

# %%
0.0045383406283339735
