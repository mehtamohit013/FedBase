# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import os
import sys

# %%
baseline_path =  '/gdrive/MyDrive/BTP/Data/baseline_data/S08'

# %%
lidar_path_train = os.path.join(baseline_path,'lidar_input','lidar_train.npz')

# %%
a = np.load(lidar_path_train)

# %%
a = a['input']

# %%
a.shape
# Out:
# (9234, 20, 200, 10)

# %%
beam_path = os.path.join(baseline_path,'beam_output')
train = 'beams_output_train.npz'
alp = os.path.join(beam_path,train)
print(alp)
b = np.load(alp)
# Out:
# /gdrive/MyDrive/BTP/Data/baseline_data/S08/beam_output/beams_output_train.npz

# %%
b.files
# Out:
# ['output_classification']

# %%
b = b['output_classification']

# %%
b.shape #[Valid Channel, Tx codebook, Rx codebook ]
# Out:
# (9234, 8, 32)

# %%
sum(sum(sum(b)))
# Out:
# (163.27214691310837+0j)

# %%
c = 'E:\BTP-Vimal Bhatia\Raymobtime_s008\\baseline_data\image_v2_input\img_input_train_20.npz'
c = np.load(c)

# %%
c.files
# Out:
# ['inputs']

# %%
c = c['inputs']

# %%
# Processed Image: 
c.shape #[Valid Channel, 48,81,1]
# Out:
# (9234, 48, 81, 1)

# %%
d = 'E:\BTP-Vimal Bhatia\Raymobtime_s008\\baseline_data\coord_input\coord_train.npz'
d = np.load(d)
d.files
# Out:
# ['coordinates']

# %%
d['coordinates'].shape #[9234,2]
# Out:
# (9234, 2)
